# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamlad21/dlon_sl/blob/main/colorify_tunnel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py39" --user
# Out:
# --2024-03-15 18:39:32--  https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61451533 (59M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  58.60M   159MB/s    in 0.4s
#
# 2024-03-15 18:39:33 (159 MB/s) - ‘mini.sh’ saved [61451533/61451533]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py39h27cfd23_1003
#     - ca-certificates==2020.12.8=h06a4308_0
#     - certifi==2020.12.5=py39h06a4308_0
#     - cffi==1.14.4=py39h261ae71_0
#     - chardet==3.0.4=py39h06a4308_1003
# ...

# %%
# !python --version
# Out:
# Python 3.9.18

# %%
# !wget -O /content/colorify.zip https://www.dropbox.com/scl/fi/9ytbdry9383xtmw41qqax/colorify.zip?rlkey=06zh5ac8poyv34f5gpxq1562j&dl=0
# !unzip /content/colorify.zip -d /content
# Out:
# --2024-03-15 18:42:03--  https://www.dropbox.com/scl/fi/9ytbdry9383xtmw41qqax/colorify.zip?rlkey=06zh5ac8poyv34f5gpxq1562j
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6030:18::a27d:5012
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc24d7cfc7ce651366981c2aee2f.dl.dropboxusercontent.com/cd/0/inline/CPK1Tuj0FJ4tfL5l7aEhdbAUT1oHTI-CrildWVb6cWus7ErbA1qPzU5Ba03szhAYZ8N-T-gFCY8xwIAEooa_rjR5uvtCk8bySWKB5P5miqEvxKFVMli8yYSflar4F-zpp7pF7oskDNMKrSW1pou2Wg6G/file# [following]
# --2024-03-15 18:42:04--  https://uc24d7cfc7ce651366981c2aee2f.dl.dropboxusercontent.com/cd/0/inline/CPK1Tuj0FJ4tfL5l7aEhdbAUT1oHTI-CrildWVb6cWus7ErbA1qPzU5Ba03szhAYZ8N-T-gFCY8xwIAEooa_rjR5uvtCk8bySWKB5P5miqEvxKFVMli8yYSflar4F-zpp7pF7oskDNMKrSW1pou2Wg6G/file
# ...

# %%
# %cd colorify
# Out:
# /content/colorify

# %%
# !python -m  pip install  -q -I -r requirements.txt
# Out:
#      |████████████████████████████████| 813 kB 5.3 MB/s
#      |████████████████████████████████| 214 kB 72.9 MB/s
#      |████████████████████████████████| 11.6 MB 73.5 MB/s
#      |████████████████████████████████| 18.2 MB 196 kB/s
#      |████████████████████████████████| 49.6 MB 155 kB/s
#      |████████████████████████████████| 4.5 MB 62.7 MB/s
#      |████████████████████████████████| 62 kB 1.4 MB/s
#      |████████████████████████████████| 34.6 MB 1.2 MB/s
#      |████████████████████████████████| 28.5 MB 1.2 MB/s
#      |████████████████████████████████| 16.8 MB 68.4 MB/s
#      |████████████████████████████████| 8.1 MB 74.8 MB/s
#      |████████████████████████████████| 755.5 MB 15 kB/s
#      |████████████████████████████████| 6.9 MB 76.4 MB/s
#      |████████████████████████████████| 147 kB 76.5 MB/s
#      |████████████████████████████████| 353 kB 70.9 MB/s
#      |████████████████████████████████| 163 kB 84.0 MB/s
# ...

# %%
# !pip install -q protobuf==3.20.*
# Out:
#      |████████████████████████████████| 1.0 MB 3.2 MB/s

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/colorify/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/colorify/package.json'
# npm WARN colorify No description
# npm WARN colorify No repository field.
# npm WARN colorify No README data
# npm WARN colorify No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 1.918s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 1 moderate severity vulnerability
#   run `npm audit fix` to fix them, or `npm audit` for details

# %%
# !streamlit run --server.runOnSave True  app.py &>/content/logs.txt &

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:",urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))
# Out:
# Password/Enpoint IP for localtunnel is: 34.87.46.0

# %%
# !npx localtunnel --port 8501
# Out:
# npx: installed 22 in 1.48s
# your url is: https://green-pets-show.loca.lt
